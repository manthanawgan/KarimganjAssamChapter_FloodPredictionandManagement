# %% [markdown]
# <a href="https://colab.research.google.com/github/manthanawgan/KarimganjAssamChapter_FloodPredictionandManagement/blob/main/Karimganj_EDA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/merged_data.csv')
df.head()
# Out:
#          Date  temperature_2m_max (°C)  temperature_2m_min (°C)  \
# 0  2015-01-01                     26.5                     18.6
# 1  2015-01-02                     27.6                     18.3
# 2  2015-01-03                     27.5                     17.9
# 3  2015-01-04                     25.2                     18.7
# 4  2015-01-05                     22.7                     13.7
#
#    temperature_2m_mean (°C)  rain_sum (mm)  precipitation_hours (h)  \
# 0                      22.3            1.2                        7
# 1                      22.5            0.0                        0
# 2                      22.9            0.0                        0
# 3                      21.3            4.7                        8
# 4                      18.3            0.2                        2
#
#    wind_speed_10m_max (m/s)  wind_gusts_10m_max (m/s)  \
# 0                      1.43                       3.8
# 1                      1.88                       5.0
# ...

# %%
#Define new column names
new_column_names = {
    "Date": "date",
    "temperature_2m_max (°C)": "temp_max",
    "temperature_2m_min (°C)": "temp_min",
    "temperature_2m_mean (°C)": "temp_mean",
    "rain_sum (mm)": "rain_mm",
    "precipitation_hours (h)": "precip_hours",
    "wind_speed_10m_max (m/s)": "wind_max",
    "wind_gusts_10m_max (m/s)": "wind_gusts",
    "wind_direction_10m_dominant (°)": "wind_dir",
    "et0_fao_evapotranspiration (mm)": "evapotranspiration",
    "unknown_discharge (m³/s)": "discharge_unknown",
    "Kushi_discharge (m³/s)": "discharge_kushi",
    "Longai_discharge (m³/s)": "discharge_longai",
    "Singla_discharge (m³/s)": "discharge_singla",
    "pressure_msl (hPa)": "pressure",
    "soil_moisture_0_to_7cm (m³/m³)": "soil_moisture_0_7",
    "soil_moisture_7_to_28cm (m³/m³)": "soil_moisture_7_28",
    "soil_moisture_28_to_100cm (m³/m³)": "soil_moisture_28_100",
    "soil_moisture_100_to_255cm (m³/m³)": "soil_moisture_100_255",
    "flooded": "flooded"
}


df.rename(columns=new_column_names, inplace=True)

# %%
#Save with new column names
df.to_csv("cleaned_data.csv", index=False)
print("Column names updated successfully!")
# Out:
# Column names updated successfully!

# %%
df.head()
# Out:
#          date  temp_max  temp_min  temp_mean  rain_mm  precip_hours  wind_max  \
# 0  2015-01-01      26.5      18.6       22.3      1.2             7      1.43
# 1  2015-01-02      27.6      18.3       22.5      0.0             0      1.88
# 2  2015-01-03      27.5      17.9       22.9      0.0             0      1.96
# 3  2015-01-04      25.2      18.7       21.3      4.7             8      3.24
# 4  2015-01-05      22.7      13.7       18.3      0.2             2      3.28
#
#    wind_gusts  wind_dir  evapotranspiration  discharge_unknown  \
# 0         3.8        65                1.73             477.63
# 1         5.0        28                2.76             475.43
# 2         4.6        22                2.69             474.34
# 3         7.6       285                2.21             466.74
# 4         8.4       293                2.37             465.66
#
#    discharge_kushi  discharge_longai  discharge_singla  pressure  \
# ...

# %%
df.apply(lambda x:sum(x.isnull()), axis=0)
# Out:
# date                     0
# temp_max                 0
# temp_min                 0
# temp_mean                0
# rain_mm                  0
# precip_hours             0
# wind_max                 0
# wind_gusts               0
# wind_dir                 0
# evapotranspiration       0
# discharge_unknown        0
# discharge_kushi          0
# discharge_longai         0
# discharge_singla         0
# pressure                 0
# soil_moisture_0_7        0
# soil_moisture_7_28       0
# soil_moisture_28_100     0
# soil_moisture_100_255    0
# flooded                  0
# dtype: int64

# %%
y = df.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: flooded, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   3654 non-null   object
#  1   temp_max               3654 non-null   float64
#  2   temp_min               3654 non-null   float64
#  3   temp_mean              3654 non-null   float64
#  4   rain_mm                3654 non-null   float64
#  5   precip_hours           3654 non-null   int64
#  6   wind_max               3654 non-null   float64
#  7   wind_gusts             3654 non-null   float64
#  8   wind_dir               3654 non-null   int64
#  9   evapotranspiration     3654 non-null   float64
#  10  discharge_unknown      3654 non-null   float64
#  11  discharge_kushi        3654 non-null   float64
#  12  discharge_longai       3654 non-null   float64
#  13  discharge_singla       3654 non-null   float64
# ...

# %%
df.describe()
# Out:
#           temp_max     temp_min    temp_mean      rain_mm  precip_hours  \
# count  3654.000000  3654.000000  3654.000000  3654.000000   3654.000000
# mean     29.057608    20.290011    24.220662     9.425698      7.788451
# std       3.295531     4.989983     3.958377    16.915257      8.283795
# min      18.400000     8.300000    13.500000     0.000000      0.000000
# 25%      26.800000    15.800000    21.000000     0.000000      0.000000
# 50%      29.600000    21.700000    25.400000     1.700000      5.000000
# 75%      31.500000    24.800000    27.400000    12.600000     15.000000
# max      37.400000    28.600000    32.000000   193.100000     24.000000
#
#           wind_max   wind_gusts     wind_dir  evapotranspiration  \
# count  3654.000000  3654.000000  3654.000000         3654.000000
# mean      2.803503     6.740887   128.991516            3.183656
# std       0.921590     2.453858   105.244328            1.017729
# ...

# %%
df.describe().T
# Out:
#                         count         mean         std      min         25%  \
# temp_max               3654.0    29.057608    3.295531   18.400    26.80000
# temp_min               3654.0    20.290011    4.989983    8.300    15.80000
# temp_mean              3654.0    24.220662    3.958377   13.500    21.00000
# rain_mm                3654.0     9.425698   16.915257    0.000     0.00000
# precip_hours           3654.0     7.788451    8.283795    0.000     0.00000
# wind_max               3654.0     2.803503    0.921590    0.920     2.20000
# wind_gusts             3654.0     6.740887    2.453858    3.000     4.80000
# wind_dir               3654.0   128.991516  105.244328    0.000    46.00000
# evapotranspiration     3654.0     3.183656    1.017729    0.440     2.51000
# discharge_unknown      3654.0  1018.786582  675.769568   20.430   470.25000
# discharge_kushi        3654.0  1405.743941  917.463724  438.540   621.30000
# ...
